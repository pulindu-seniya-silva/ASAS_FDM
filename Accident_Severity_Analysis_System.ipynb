# %% [markdown]
# <a href="https://colab.research.google.com/github/pulindu-seniya-silva/ASAS_FDM/blob/main/Accident_Severity_Analysis_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('Road Accident Data.csv')
df
# Out:
#        Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 0           BS0000001      1/1/2021    Thursday      Give way or uncontrolled
# 1           BS0000002      5/1/2021      Monday      Give way or uncontrolled
# 2           BS0000003      4/1/2021      Sunday      Give way or uncontrolled
# 3           BS0000004      5/1/2021      Monday           Auto traffic signal
# 4           BS0000005      6/1/2021     Tuesday           Auto traffic signal
# ...               ...           ...         ...                           ...
# 107697      BS0107698    13-05-2021   Wednesday  Data missing or out of range
# 107698      BS0107699      9/7/2021    Thursday  Data missing or out of range
# 107699      BS0107700     7/11/2021    Saturday      Give way or uncontrolled
# 107700      BS0107701    14-01-2021   Wednesday  Data missing or out of range
# 107701      BS0107702     10/2/2021     Tuesday  Data missing or out of range
#
#                             Junction_Detail Accident_Severity   Latitude  \
# 0                   T or staggered junction           Serious  51.512273
# 1                                Crossroads           Serious  51.514399
# 2                   T or staggered junction            Slight  51.486668
# 3                   T or staggered junction           Serious  51.507804
# 4                                Crossroads           Serious  51.482076
# ...                                     ...               ...        ...
# 107697  Not at junction or within 20 metres            Slight  51.608894
# 107698            Private drive or entrance            Slight  51.710785
# 107699              T or staggered junction           Serious  51.582724
# 107700            Private drive or entrance            Slight  51.610776
# 107701  Not at junction or within 20 metres            Slight  51.749521
#
#               Light_Conditions Local_Authority_(District) Carriageway_Hazards  \
# 0                     Daylight     Kensington and Chelsea                 NaN
# 1                     Daylight     Kensington and Chelsea                 NaN
# 2                     Daylight     Kensington and Chelsea                 NaN
# 3                     Daylight     Kensington and Chelsea                 NaN
# 4        Darkness - lights lit     Kensington and Chelsea                 NaN
# ...                        ...                        ...                 ...
# 107697                Daylight                    Wycombe                 NaN
# 107698                Daylight                   Chiltern                 NaN
# 107699                Daylight                    Wycombe                 NaN
# 107700   Darkness - lights lit                    Wycombe                 NaN
# 107701  Darkness - no lighting                   Chiltern                 NaN
#
#         ...  Number_of_Casualties  Number_of_Vehicles         Police_Force  \
# 0       ...                   1.0                 2.0  Metropolitan Police
# 1       ...                  11.0                 2.0  Metropolitan Police
# 2       ...                   1.0                 2.0  Metropolitan Police
# 3       ...                   1.0                 2.0  Metropolitan Police
# 4       ...                   1.0                 2.0  Metropolitan Police
# ...     ...                   ...                 ...                  ...
# 107697  ...                   1.0                 1.0        Thames Valley
# 107698  ...                   1.0                 1.0        Thames Valley
# 107699  ...                   4.0                 2.0        Thames Valley
# 107700  ...                   1.0                 4.0        Thames Valley
# 107701  ...                   NaN                 NaN                  NaN
#
#        Road_Surface_Conditions           Road_Type Speed_limit   Time  \
# 0                          Dry      One way street        30.0  15:11
# 1                  Wet or damp  Single carriageway        30.0  10:59
# 2                          Dry  Single carriageway        30.0  14:19
# 3                 Frost or ice  Single carriageway        30.0   8:10
# 4                          Dry  Single carriageway        30.0  17:25
# ...                        ...                 ...         ...    ...
# 107697                     Dry    Dual carriageway        70.0  13:13
# 107698                     Dry  Single carriageway        30.0   8:20
# 107699                     Dry  Single carriageway        60.0  11:42
# 107700                     Dry  Single carriageway        30.0  17:09
# 107701                     NaN                 NaN         NaN    NaN
#
#        Urban_or_Rural_Area  Weather_Conditions           Vehicle_Type
# 0                    Urban  Fine no high winds                    Car
# 1                    Urban  Fine no high winds  Taxi/Private hire car
# 2                    Urban  Fine no high winds  Taxi/Private hire car
# 3                    Urban               Other  Motorcycle over 500cc
# 4                    Urban  Fine no high winds                    Car
# ...                    ...                 ...                    ...
# 107697               Rural  Fine no high winds  Motorcycle over 500cc
# 107698               Urban  Fine no high winds                    Car
# 107699               Rural  Fine no high winds                    Car
# 107700               Urban  Fine no high winds                    Car
# 107701                 NaN                 NaN                    NaN
#
# [107702 rows x 21 columns]
